# %% [markdown]
# # Introduction

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# # Comparing across all degree categories

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
all_cats = [stem_cats, lib_arts_cats, other_cats]
fig = plt.figure(figsize=(24,18))

for cat_idx, cat in enumerate(all_cats):
    total_sp = len(cat)
    for sp_idx, sp in enumerate(cat):
        ax = fig.add_subplot(6,3,sp_idx*3+cat_idx+1)
        # Data
        ax.plot(women_degrees['Year'], women_degrees[sp], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[sp], c=cb_orange, label='Women', linewidth=3)
        # Hide Spine
        for _, spine in ax.spines.items():
            spine.set_visible(False)
        # Other decorations
        ax.set_xlim(1968,2011)
        ax.set_ylim(0,100)
        ax.set_title(sp)
        ax.tick_params(top=False, right=False, bottom=False, left=False)
        
        women_degree_percent_in_2002 = women_degrees[women_degrees['Year'] == 2002][sp].iloc[0]
        if women_degree_percent_in_2002 >= 50:
            women_label_y_pos = women_degree_percent_in_2002 + 10
        else:
            women_label_y_pos = women_degree_percent_in_2002 - 10

        men_degree_percent_in_2005 = 100 - women_degrees[women_degrees['Year'] == 2005][sp].iloc[0]
        if men_degree_percent_in_2005 >= 50:
            men_label_y_pos = men_degree_percent_in_2005 + 10
        else:
            men_label_y_pos = men_degree_percent_in_2005 - 10

        if sp_idx == 0 or sp_idx == total_sp - 1 and cat_idx != 1:
            ax.text(2005, men_label_y_pos, 'Men')
            ax.text(2002, women_label_y_pos, 'Women')
    
plt.show()

# %% [markdown]
# ## Hiding x-axis label

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
all_cats = [stem_cats, lib_arts_cats, other_cats]
fig = plt.figure(figsize=(24,18))

for cat_idx, cat in enumerate(all_cats):
    total_sp = len(cat)
    for sp_idx, sp in enumerate(cat):
        ax = fig.add_subplot(6,3,sp_idx*3+cat_idx+1)
        # Data
        ax.plot(women_degrees['Year'], women_degrees[sp], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[sp], c=cb_orange, label='Women', linewidth=3)
        # Hide Spine
        for _, spine in ax.spines.items():
            spine.set_visible(False)
        # Other decorations
        ax.set_xlim(1968,2011)
        ax.set_ylim(0,100)
        ax.set_title(sp)
        ax.tick_params(top=False, right=False, bottom=False, left=False,
                       labelbottom=False)
        
        # Calculating label position (under or above the line)
        women_degree_percent_in_2002 = women_degrees[women_degrees['Year'] == 2002][sp].iloc[0]
        if women_degree_percent_in_2002 >= 50:
            women_label_y_pos = women_degree_percent_in_2002 + 10
        else:
            women_label_y_pos = women_degree_percent_in_2002 - 10

        men_degree_percent_in_2005 = 100 - women_degrees[women_degrees['Year'] == 2005][sp].iloc[0]
        if men_degree_percent_in_2005 >= 50:
            men_label_y_pos = men_degree_percent_in_2005 + 10
        else:
            men_label_y_pos = men_degree_percent_in_2005 - 10

        if sp_idx == 0 or sp_idx == total_sp - 1 and cat_idx != 1:
            ax.text(2005, men_label_y_pos, 'Men')
            ax.text(2002, women_label_y_pos, 'Women')
    
plt.show()

# %% [markdown]
# ## Setting y-axis label

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
all_cats = [stem_cats, lib_arts_cats, other_cats]
fig = plt.figure(figsize=(24,18))

for cat_idx, cat in enumerate(all_cats):
    total_sp = len(cat)
    for sp_idx, sp in enumerate(cat):
        ax = fig.add_subplot(6,3,sp_idx*3+cat_idx+1)
        # Data
        ax.plot(women_degrees['Year'], women_degrees[sp], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[sp], c=cb_orange, label='Women', linewidth=3)
        # Hide Spine
        for _, spine in ax.spines.items():
            spine.set_visible(False)
        # Other decorations
        ax.set_xlim(1968,2011)
        ax.set_ylim(0,100)
        ax.set_title(sp)
        ax.tick_params(top=False, right=False, bottom=False, left=False,
                       labelbottom=False)
        ax.set_yticks([0,100])
        
        # Calculating label position (under or above the line)
        women_degree_percent_in_2002 = women_degrees[women_degrees['Year'] == 2002][sp].iloc[0]
        if women_degree_percent_in_2002 >= 50:
            women_label_y_pos = women_degree_percent_in_2002 + 10
        else:
            women_label_y_pos = women_degree_percent_in_2002 - 10

        men_degree_percent_in_2005 = 100 - women_degrees[women_degrees['Year'] == 2005][sp].iloc[0]
        if men_degree_percent_in_2005 >= 50:
            men_label_y_pos = men_degree_percent_in_2005 + 10
        else:
            men_label_y_pos = men_degree_percent_in_2005 - 10

        if sp_idx == 0 or sp_idx == total_sp - 1 and cat_idx != 1:
            ax.text(2005, men_label_y_pos, 'Men')
            ax.text(2002, women_label_y_pos, 'Women')
    
plt.show()

# %% [markdown]
# ## Adding a horizontal line

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
all_cats = [stem_cats, lib_arts_cats, other_cats]
fig = plt.figure(figsize=(24,18))

for cat_idx, cat in enumerate(all_cats):
    total_sp = len(cat)
    for sp_idx, sp in enumerate(cat):
        ax = fig.add_subplot(6,3,sp_idx*3+cat_idx+1)
        # Data
        ax.plot(women_degrees['Year'], women_degrees[sp], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[sp], c=cb_orange, label='Women', linewidth=3)
        # Hide Spine
        for _, spine in ax.spines.items():
            spine.set_visible(False)
        # Other decorations
        ax.set_xlim(1968,2011)
        ax.set_ylim(0,100)
        ax.set_title(sp)    
        ax.tick_params(top=False, right=False, bottom=False, left=False,
                       labelbottom=False)
        # Hide all y-axis ticks except '0' and '100'
        ax.set_yticks([0,100])
        # Add a horizontal line
        ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)
        
        # Calculating label position (under or above the line)
        women_degree_percent_in_2002 = women_degrees[women_degrees['Year'] == 2002][sp].iloc[0]
        if women_degree_percent_in_2002 >= 50:
            women_label_y_pos = women_degree_percent_in_2002 + 10
        else:
            women_label_y_pos = women_degree_percent_in_2002 - 10

        men_degree_percent_in_2005 = 100 - women_degrees[women_degrees['Year'] == 2005][sp].iloc[0]
        if men_degree_percent_in_2005 >= 50:
            men_label_y_pos = men_degree_percent_in_2005 + 10
        else:
            men_label_y_pos = men_degree_percent_in_2005 - 10

        if sp_idx == 0 or sp_idx == total_sp - 1 and cat_idx != 1:
            ax.text(2005, men_label_y_pos, 'Men')
            ax.text(2002, women_label_y_pos, 'Women')
    
plt.show()

# %% [markdown]
# # Export & save the figure

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
all_cats = [stem_cats, lib_arts_cats, other_cats]
fig = plt.figure(figsize=(18,18))

for cat_idx, cat in enumerate(all_cats):
    total_sp = len(cat)
    for sp_idx, sp in enumerate(cat):
        ax = fig.add_subplot(6,3,sp_idx*3+cat_idx+1)
        # Data
        ax.plot(women_degrees['Year'], women_degrees[sp], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[sp], c=cb_orange, label='Women', linewidth=3)
        # Hide Spine
        for _, spine in ax.spines.items():
            spine.set_visible(False)
        # Other decorations
        ax.set_xlim(1968,2011)
        ax.set_ylim(0,100)
        ax.set_title(sp)    
        ax.tick_params(top=False, right=False, bottom=False, left=False,
                       labelbottom=False)
        # Hide all y-axis ticks except '0' and '100'
        ax.set_yticks([0,100])
        # Add a horizontal line
        ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)
        
        # Calculating label position (under or above the line)
        women_degree_percent_in_2002 = women_degrees[women_degrees['Year'] == 2002][sp].iloc[0]
        if women_degree_percent_in_2002 >= 50:
            women_label_y_pos = women_degree_percent_in_2002 + 10
        else:
            women_label_y_pos = women_degree_percent_in_2002 - 10

        men_degree_percent_in_2005 = 100 - women_degrees[women_degrees['Year'] == 2005][sp].iloc[0]
        if men_degree_percent_in_2005 >= 50:
            men_label_y_pos = men_degree_percent_in_2005 + 10
        else:
            men_label_y_pos = men_degree_percent_in_2005 - 10

        if sp_idx == 0 or sp_idx == total_sp - 1 and cat_idx != 1:
            ax.text(2005, men_label_y_pos, 'Men')
            ax.text(2002, women_label_y_pos, 'Women')
    
plt.savefig('gender_degrees.png')
plt.show()
